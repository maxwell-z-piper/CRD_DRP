# %%
from kcwikit.kcwi import kcwi
import os

# change the following directory to where the data files live + where the .list and .par files live
os.chdir('/Volumes/Mainframe/KCWI/KcwiKit_Redux/redux/kskywizard')

# enter the name of the .list file for which cubes to stack.
fn = 'blue_kskywizard.list'
kcwi.kcwi_align(fn, noalign=True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60670.000000 from DATE-OBS.
# Set MJD-BEG to 60670.459299 from DATE-BEG.
# Set MJD-END to 60670.474577 from DATE-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60670.000000 from DATE-OBS.
# Set MJD-BEG to 60670.459299 from DATE-BEG.
# Set MJD-END to 60670.474577 from DATE-END'. [astropy.wcs.wcs]
# kb241226_00119_icubes.fits

# %%
# Inspect the _fn_.thum0.fits file in QFitsView and choose box coordinates that encompass the entire galaxy.
# Enter these box coordinates in the corresponding .par file.

# %%
kcwi.kcwi_align(fn)
# Out:
# kb241226_00119_icubes.fits
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60670.000000 from DATE-OBS.
# Set MJD-BEG to 60670.459299 from DATE-BEG.
# Set MJD-END to 60670.474577 from DATE-END'. [astropy.wcs.wcs]

# %%
# Inspect the created .png images to ensure that the center cross is on the center of the galaxy. If not, need to rerun
# the above and choose a better box (probably smaller)

# %%
kcwi.kcwi_stack(fn, drizzle=0.9, overwrite=True)
# Out:
# Projecting...
# kb241226_00119_icubes.fits
#      CRVAL (original) = 3375.0
# Skipping air-to-vac conversion, already done.
# Skipping heliocentric/barycentric correction, already done.
# kcwi_vachelio - Already processed. Returning.
#      Vcorr = -23.615901520054347
#      EXPTIME = 1320.0
# /Users/maxpiper/KcwiKit/kcwikit/kcwi/kcwi.py:1489: RuntimeWarning: invalid value encountered in cast
#   hdu_i.data = (hdu_i.data * fac_i).astype(dtype)
# /Users/maxpiper/KcwiKit/kcwikit/kcwi/kcwi.py:1490: RuntimeWarning: invalid value encountered in cast
#   hdu_v.data = (hdu_v.data * fac_v).astype(dtype)
# Stacking...
#   0%|                                                                                                                                                    | 0/67 [00:00<?, ?it/s]/Users/maxpiper/KcwiKit/kcwikit/kcwi/kcwi.py:1711: RuntimeWarning: invalid value encountered in divide
#   data_3d[ii,:,:]=np.transpose(np.nansum(img*weight,axis=0)/np.nansum(weight,axis=0))
# ...
